# %%
print("Hello Python!")
# Out:
# Hello Python!

# %%
# Simple way to get input data from console
input_string_var = input("Enter some data: ") 
print(input_string_var)
# Out:
# Enter some data:  How are you?
# How are you?

# %%
# if can be used as an expression
"yay!" if 0 > 1 else "nay!"
# Out:
# 'nay!'

# %%
| Type       | Ordered | Mutable | Duplicates  | Syntax        |Example
| ---------- | ------- | ------- | ----------- | ------------- |-------------
| List       | Yes     | Yes     | Yes         | `[ ]`         | my_list = [1,2,3]
| Tuple      | Yes     | No      | Yes         | `( )`         | my_tuple = (1,2,3)
| Dictionary | Yes*    | Yes     | Keys unique | `{key:value}` | my_dict = {"a":1, "b":2}
| Set        | No      | Yes     | No          | `{ }`         | my_set = {1,2,3}

*Dictionaries preserve insertion order in modern Python.

# %% [markdown]
#  ## List

# %%
fruits = ["apple", "banana", "mango"]
print("fruits-->",fruits)

fruits.pop()  # Remove from the end with pop
print(fruits)

fruits.append("grapes"); # Add stuff to the end of a list with append. It takes exactly one argument
print(fruits)

fruits.extend(["pear","apple","kiwi","pineapple"]) # It takes more than one argument
print(fruits)

#fruits.extend("pearapple") -> ['apple', 'banana', 'grapes', 'pear', 'apple', 'p', 'e', 'a', 'r', 'a', 'p', 'p', 'l', 'e']

# The start index is included, the end index is not, # li[start:end:step]
slice_fruits = fruits[2:4] # ['grapes', 'pear']
slice_fruits = fruits[3:] # ['pear', 'apple', 'kiwi', 'pineapple']
slice_fruits = fruits[:4] # ['apple', 'banana', 'grapes', 'pear']
slice_fruits = fruits[::3] # ['apple', 'pear', 'pineapple']
slice_fruits = fruits[::-1] # ['pineapple', 'kiwi', 'apple', 'pear', 'grapes', 'banana', 'apple']
slice_fruits = fruits[3::-1] # ['pear', 'grapes', 'banana', 'apple']


print(fruits[0]) # Access a list like you would any array
print(fruits[-1]) # Look at the last element
print(fruits[5]) # Looking out of bounds is an IndexError

# Examine the length with "len()"
len(fruits)  # => 7   # ['apple', 'banana', 'grapes', 'pear', 'apple', 'kiwi', 'pineapple']

fruits.remove("apple")
 # ['banana', 'grapes', 'pear', 'apple', 'kiwi', 'pineapple']

del fruits[2]  # Remove arbitrary elements from a list with "del"
 #['banana', 'grapes', 'apple', 'kiwi', 'pineapple']

fruits.insert(1, "apple");
print("*: ",fruits)

# Get the index of the first item found matching the argument
fruits.index("apple")  # => 1
# fruits.index("guava")  # Raises a ValueError as guava is not in the list

vegetables = ["Carrot", "beans"]
fruits + vegetables  #['banana', 'apple', 'grapes', 'apple', 'kiwi', 'pineapple', 'Carrot', 'beans']

# Concatenate lists with "extend()"
fruits.extend(vegetables)  #extend() does not return the new list.It only changes the original list.
print(fruits)  #['banana', 'apple', 'grapes', 'apple', 'kiwi', 'pineapple', 'Carrot', 'beans']

# Check for existence in a list with "pear"
"kiwi" in fruits  # => True
# Out:
# fruits--> ['apple', 'banana', 'mango']
# ['apple', 'banana']
# ['apple', 'banana', 'grapes']
# ['apple', 'banana', 'grapes', 'pear', 'apple', 'kiwi', 'pineapple']
# apple
# pineapple
# kiwi
# *:  ['banana', 'apple', 'grapes', 'apple', 'kiwi', 'pineapple']
# ['banana', 'apple', 'grapes', 'apple', 'kiwi', 'pineapple', 'Carrot', 'beans']
# True

# %%
# Tuple
coordinates = (10, 20)
print(coordinates)
# Out:
# (10, 20)

# %%
# Dictionary
student = {"name": "Sara", "age": 22}
print(student)
# Out:
# {'name': 'Sara', 'age': 22}

# %%
# Set
unique_numbers = {5,7,6,6,1,9,2,2,3,4}
print(unique_numbers)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9}
